# %%
# REGRESSION MODEL
import pandas as pd
df = pd.read_csv('/content/chennai_rainfall_2019_2023_mm.csv')
from sklearn.preprocessing import MinMaxScaler
mm = MinMaxScaler()
df[['Humidity (%)','Temperature (°C)','Wind Speed (km/h)']] = mm.fit_transform(df[['Humidity (%)','Temperature (°C)','Wind Speed (km/h)']])
df['Rainfall (mm)'] = mm.fit_transform(df[['Rainfall (mm)']])
X = df[['Humidity (%)','Temperature (°C)','Wind Speed (km/h)']]
Y = df['Rainfall (mm)']
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, Y_test = train_test_split(
    X, Y, test_size=0.2, random_state=42
)
from sklearn.ensemble import RandomForestRegressor
regr = RandomForestRegressor()
regr.fit(X_train, y_train)
y_pred = regr.predict(X_test)
from sklearn.metrics import accuracy_score, r2_score, mean_squared_error
import numpy as np
r2 = r2_score(Y_test, y_pred)
rmse = np.sqrt(mean_squared_error(Y_test, y_pred))
print(f'R² Score: {r2:.4f}')
print(f'RMSE: {rmse:.4f}')
# Out:
# R² Score: -0.0929
# RMSE: 0.1598

# %%
# CLASSIFIER MODEL

import pandas as pd
df = pd.read_csv('/content/chennai_rainfall_2019_2023_mm.csv')
X = df[['Humidity (%)','Temperature (°C)','Wind Speed (km/h)']]
Y = df['Rainfall (mm)']
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, Y_test = train_test_split(
    X, Y, test_size=0.2, random_state=42
)
from sklearn.ensemble import RandomForestClassifier
clf = RandomForestClassifier()
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)
from sklearn.metrics import accuracy_score, r2_score
accuracy_score = accuracy_score(Y_test, y_pred)
r2 = r2_score(Y_test, y_pred)
print(f'R² Score: {r2:.4f}')
print(f'accuracy_score: {accuracy_score:.4f}')
# Out:
# R² Score: -0.6071
# accuracy_score: 0.1093
